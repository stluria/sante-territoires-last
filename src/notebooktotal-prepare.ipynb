# %%
"""
C2/C3 - Nettoyage et préparation des données FINESS
=====================================================
- Normalisation des colonnes (noms, types)
- Gestion des doublons
- Nettoyage des valeurs nulles et formats
- Filtrage Occitanie (région 76, départements 09,11,12,30,31,32,34,46,48,65,66,81,82)
- Règles d'agrégation pour combiner les 3 sources
- Géoréférencement (Lambert93 → WGS84)
"""
import logging
import os
import plotly.express as px
import pandas as pd
import math
from pyproj import Transformer

from pathlib import Path

#BASE_DIR = Path(__file__).resolve().parent  # dossier du .py
df_soins = pd.read_csv( "../data/raw/finess_activites_soins.csv", sep=";", encoding="utf-8")




df_communes = pd.read_csv( "../data/raw/v_commune_2025.csv", sep=",", encoding="utf-8",dtype={
     1: "string",  # colonne 0
        9: "string",   # colonne 1
        11: "string",   # colonne 1
        13: "string",   # colonne 1
        17: "string"   # colonne 1
    })
df_etab = pd.read_csv( "../data/raw/finess_etablissements.txt", sep=";", encoding="utf-8", dtype={
        0: "string",  # colonne 0
        1: "string",   # colonne 1
        12: "string"   # colonne 1
    })
df_equi = pd.read_csv( "../data/raw/finess_equipements_sociaux.csv", sep=";", encoding="utf-8", dtype={
        0: "string",  # colonne 0
        1: "string"   # colonne 1
    })


# ---------------------------------------------------------------------------
# Fonctions de nettoyage
# ---------------------------------------------------------------------------

def clean_nofiness(series: pd.Series) -> pd.Series:
    """
    Normalise les numéros FINESS : chaîne de 9 caractères, zéros à gauche.
    Exemples : 10001246 → '010001246', 310001234 → '310001234'
    """
    return series.astype(str).str.zfill(9)


def clean_department(code: str) -> str:
    """Normalise un code département : '9' → '09', '31' → '31'."""
    if pd.isna(code):
        return None
    code = str(code).strip().zfill(2)
    return code[:2]  # Garde uniquement les 2 premiers chiffres


def lambert93_to_wgs84(x: float, y: float):
    """
    Convertit des coordonnées Lambert93 (EPSG:2154) en WGS84 (lat/lon).
    Implémentation pure Python basée sur les paramètres IAG GRS80.
    """
    try:
        if pd.isna(x) or pd.isna(y) or float(x) == 0 or float(y) == 0:
            return None, None
        x, y = float(x), float(y)

        # Paramètres ellipsoïde GRS80
        a = 6378137.0
        e = 0.0818191910428158

        # Paramètres projection Lambert93
        lc = math.radians(3.0)          # Longitude centrale
        phi0 = math.radians(46.5)       # Latitude d'origine
        phi1 = math.radians(44.0)       # Parallèle 1
        phi2 = math.radians(49.0)       # Parallèle 2
        x0 = 700000.0
        y0 = 6600000.0

        def _geo_lat(phi):
            sp = e * math.sin(phi)
            return math.tan(math.pi / 4 + phi / 2) * ((1 - sp) / (1 + sp)) ** (e / 2)

        m1 = math.cos(phi1) / math.sqrt(1 - (e * math.sin(phi1)) ** 2)
        m2 = math.cos(phi2) / math.sqrt(1 - (e * math.sin(phi2)) ** 2)
        t1 = _geo_lat(phi1)
        t2 = _geo_lat(phi2)
        t0 = _geo_lat(phi0)

        n = math.log(m1 / m2) / math.log(t1 / t2)
        F = m1 / (n * t1 ** n)
        r0 = a * F * t0 ** n

        dx, dy = x - x0, y - y0 + r0
        r = math.sqrt(dx ** 2 + dy ** 2) * math.copysign(1, n)
        theta = math.atan(dx / (r0 - (y - y0)))
        lon = math.degrees(theta / n + lc)

        t = (r / (a * F)) ** (1 / n)
        phi = math.pi / 2 - 2 * math.atan(t)
        for _ in range(10):
            sp = e * math.sin(phi)
            phi = math.pi / 2 - 2 * math.atan(t * ((1 - sp) / (1 + sp)) ** (e / 2))

        lat = math.degrees(phi)

        if 41 <= lat <= 52 and -5 <= lon <= 10:
            return round(lat, 6), round(lon, 6)
        return None, None
    except Exception:
        return None, None

   



df_soins.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
#      11 import logging
#      12 import os
# ---> 13 import plotly.express as px
#      14 import pandas as pd
#      15 import math
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotly/express/__init__.py:28
#      12     raise ImportError(
#      13         """\
#      14 Plotly Express requires numpy to be installed. You can install numpy using pip with:
#    (...)     24 """
#      25     )
#      27 from ._imshow import imshow
# ---> 28 from ._chart_types import (  # noqa: F401
#      29     scatter,
#      30     scatter_3d,
#      31     scatter_polar,
#      32     scatter_ternary,
#      33     scatter_map,
#      34     scatter_mapbox,
#      35     scatter_geo,
#      36     line,
#      37     line_3d,
#      38     line_polar,
#      39     line_ternary,
#      40     line_map,
#      41     line_mapbox,
#      42     line_geo,
#      43     area,
#      44     bar,
#      45     timeline,
#      46     bar_polar,
#      47     violin,
#      48     box,
#      49     strip,
#      50     histogram,
#      51     ecdf,
#      52     scatter_matrix,
#      53     parallel_coordinates,
#      54     parallel_categories,
#      55     choropleth,
#      56     density_contour,
#      57     density_heatmap,
#      58     pie,
#      59     sunburst,
#      60     treemap,
#      61     icicle,
#      62     funnel,
#      63     funnel_area,
#      64     choropleth_map,
#      65     choropleth_mapbox,
#      66     density_map,
#      67     density_mapbox,
#      68 )
#      71 from ._core import (  # noqa: F401
#      72     set_mapbox_access_token,
#      73     defaults,
#      74     get_trendline_results,
#      75     NO_COLOR,
#      76 )
#      78 from ._special_inputs import IdentityMap, Constant, Range  # noqa: F401
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotly/express/_chart_types.py:329
#     317     """
#     318     In a stacked area plot, each row of `data_frame` is represented as
#     319     a vertex of a polyline mark in 2D space. The area between
#     320     successive polylines is filled.
#     321     """
#     322     return make_figure(
#     323         args=locals(),
#     324         constructor=go.Scatter,
#     325         trace_patch=dict(stackgroup=1, mode="lines", groupnorm=groupnorm),
#     326     )
# --> 329 area.__doc__ = make_docstring(area, append_dict=_cartesian_append_dict)
#     332 def bar(
#     333     data_frame=None,
#     334     x=None,
#    (...)    375     height=None,
#     376 ) -> go.Figure:
#     377     """
#     378     In a bar plot, each row of `data_frame` is represented as a rectangular
#     379     mark.
#     380     """
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotly/express/_doc.py:631, in make_docstring(fn, override_dict, append_dict)
#     628         param_doc += append_dict[param]
#     629 param_desc_list = param_doc[1:]
#     630 param_desc = (
# --> 631     tw.fill(" ".join(param_desc_list or ""))
#     632     if param in docs or param in override_dict
#     633     else "(documentation missing from map)"
#     634 )
#     636 param_type = param_doc[0]
#     637 result += "%s: %s\n%s\n" % (param, param_type, param_desc)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/textwrap.py:368, in TextWrapper.fill(self, text)
#     361 def fill(self, text):
#     362     """fill(text : string) -> string
#     363
#     364     Reformat the single paragraph in 'text' to fit in lines of no
#     365     more than 'self.width' columns, and return a new string
#     366     containing the entire wrapped paragraph.
#     367     """
# --> 368     return "\n".join(self.wrap(text))
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/textwrap.py:359, in TextWrapper.wrap(self, text)
#     357 if self.fix_sentence_endings:
#     358     self._fix_sentence_endings(chunks)
# --> 359 return self._wrap_chunks(chunks)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/textwrap.py:292, in TextWrapper._wrap_chunks(self, chunks)
#     290 # Can at least squeeze this chunk onto the current line.
#     291 if cur_len + l <= width:
# --> 292     cur_line.append(chunks.pop())
#     293     cur_len += l
#     295 # Nope, this line is full.
#     296 else:
#
# KeyboardInterrupt:

# %%
#nettoyage activité soins
# Sélection des colonnes utiles
cols = ["nofinesset", "rsej", "libactivite", "libmodalite", "libforme", "datefin"]
df_soins = df_soins[[c for c in cols if c in df_soins.columns]].copy()
#nettoyage nofinesset
df_soins["nofinesset"] = clean_nofiness(df_soins["nofinesset"])

# %%
# Regroupement des catégories d'activités pour les soins
def regrouper_categorie(cat):
    cat = cat.lower()

    if any(x in cat for x in ["greffe"]):
        return "Greffe"

    if any(x in cat for x in ["soins de suite"]):
        return "Soins de suite"

    if any(x in cat for x in ["chirurgie"]):
        return "Chirurgie"
    if any(x in cat for x in ["médecine d\'urgence"]):
        return "Médecine d'urgence"
    if any(x in cat for x in ["médecine"]):
        return "Médecine"
    if any(x in cat for x in ["médecine"]):
        return "Médecine"
    if any(x in cat for x in ["psychiatrie"]):
        return "Psychiatrie"
    if any(x in cat for x in ["amp dpn"]):
        return "AMP DPN"
    if any(x in cat for x in ["cancer"]):
        return "Cancer"
    if any(x in cat for x in ["gynécologie"]):
        return "Gynécologie"
    if any(x in cat for x in ["soins de longue durée"]):
        return "Soins de longue durée"
    if any(x in cat for x in ["insuffisance rénale"]):
        return "Insuffisance rénale"
    if any(x in cat for x in ["examen des caractéristiques génétiques"]):
        return "Examen des caractéristiques génétiques"
    return "Autres"

# Application
df_soins["groupe_activites"] = df_soins["libactivite"].apply(regrouper_categorie)

#enlever les doublons 
df_soins = df_soins.drop_duplicates()

# %%
df_etab.head()
# Out:
#   nofinesset nofinessej                           rs  \
# 0   10000024   10780054               CH DE FLEYRIAT
# 1   10000032   10780062                 CH BUGEY SUD
# 2   10000065   10780096  CH DE TREVOUX - MONTPENSIER
# 3   10000081   10780112            CH DU PAYS DE GEX
# 4   10000099   10780120              CH DE MEXIMIEUX
#
#                                          rslongue complrs compldistrib  \
# 0  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT     NaN          NaN
# 1                    CENTRE HOSPITALIER BUGEY SUD     NaN          NaN
# 2     CENTRE HOSPITALIER DE TREVOUX - MONTPENSIER     NaN          NaN
# 3               CENTRE HOSPITALIER DU PAYS DE GEX     NaN          NaN
# 4                 CENTRE HOSPITALIER DE MEXIMIEUX     NaN          NaN
#
#    numvoie typvoie              voie compvoie  ... codesph  \
# 0    900.0     RTE          DE PARIS      NaN  ...     1.0
# 1    700.0      AV         DE NARVIK      NaN  ...     1.0
# 2     14.0       R      DE L'HOPITAL      NaN  ...     1.0
# 3    160.0       R     MARC PANISSOD      NaN  ...     1.0
# 4     13.0      AV  DU DOCTEUR BOYER      NaN  ...     1.0
#
#                           libsph     dateouv   dateautor     datemaj  numuai  \
# 0  Etablissement public de santé  1979-02-13  1979-02-13  2020-02-04     NaN
# 1  Etablissement public de santé  1901-01-01  1901-01-01  2021-07-07     NaN
# 2  Etablissement public de santé  1901-01-01  1901-01-01  2018-01-12     NaN
# 3  Etablissement public de santé  1901-01-01  1901-01-01  2020-02-04     NaN
# 4  Etablissement public de santé  1945-01-01  1945-01-01  2020-06-30     NaN
#
#    coordxet   coordyet                                      sourcecoordet  \
# 0  870262.2  6571540.8  1,ATLASANTE,96,BAN,EPSG:2154 RGF93 / Lambert-9...
# 1  908313.3  6520061.2  1,ATLASANTE,95,BAN,EPSG:2154 RGF93 / Lambert-9...
# 2  837272.3  6539470.4  1,ATLASANTE,85,BAN,EPSG:2154 RGF93 / Lambert-9...
# 3  935221.3  6584833.3  1,ATLASANTE,85,BAN,EPSG:2154 RGF93 / Lambert-9...
# 4  870118.2  6536469.4  1,ATLASANTE,96,BAN,EPSG:2154 RGF93 / Lambert-9...
#
#    datemaj_geoloc
# 0      2026-01-05
# 1      2026-01-05
# 2      2026-01-05
# 3      2026-01-05
# 4      2026-01-05
#
# [5 rows x 35 columns]

# %%
#verification des codes communes : 3 chiffres
df_etab["commune"] = (
    df_etab["commune"]
        .astype("Int64")  # gère les NA proprement
        .astype(str)
        .str.zfill(3)
)

# %%
#nettoyage établissement
# Sélection des colonnes utiles
cols = ["nofinesset", "nofinessej","rs", "rslongue", "departement","commune","complrs","compldistrib","numvoie","typvoie","voie","compvoie","lieuditbp", "libdepartement", "libcategetab", "libcategagretab","coordxet", "coordyet"]
df_etab = df_etab[[c for c in cols if c in df_etab.columns]].copy()
#nettoyage nofinesset
df_etab["nofinesset"] = clean_nofiness(df_etab["nofinesset"])

# %%
def clean_department(code: str) -> str:
    """Normalise un code département : '9' → '09', '31' → '31'."""
    if pd.isna(code):
        return None
    code = str(code).strip().zfill(2)
    return code[:2]  # Garde uniquement les 2 premiers chiffres

df_etab["departement"] = df_etab["departement"].apply(clean_department)

# %%
df_etab.head()
# Out:
#   nofinesset nofinessej                           rs  \
# 0  010000024  010780054               CH DE FLEYRIAT
# 1  010000032  010780062                 CH BUGEY SUD
# 2  010000065  010780096  CH DE TREVOUX - MONTPENSIER
# 3  010000081  010780112            CH DU PAYS DE GEX
# 4  010000099  010780120              CH DE MEXIMIEUX
#
#                                          rslongue departement commune complrs  \
# 0  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT          01     451     NaN
# 1                    CENTRE HOSPITALIER BUGEY SUD          01     034     NaN
# 2     CENTRE HOSPITALIER DE TREVOUX - MONTPENSIER          01     427     NaN
# 3               CENTRE HOSPITALIER DU PAYS DE GEX          01     173     NaN
# 4                 CENTRE HOSPITALIER DE MEXIMIEUX          01     244     NaN
#
#   compldistrib  numvoie typvoie              voie compvoie lieuditbp  \
# 0          NaN    900.0     RTE          DE PARIS      NaN       NaN
# 1          NaN    700.0      AV         DE NARVIK      NaN    BP 139
# 2          NaN     14.0       R      DE L'HOPITAL      NaN    BP 615
# 3          NaN    160.0       R     MARC PANISSOD      NaN    BP 437
# 4          NaN     13.0      AV  DU DOCTEUR BOYER      NaN       NaN
#
#   libdepartement                          libcategetab       libcategagretab  \
# 0            AIN             Centre Hospitalier (C.H.)  Centres Hospitaliers
# 1            AIN             Centre Hospitalier (C.H.)  Centres Hospitaliers
# 2            AIN             Centre Hospitalier (C.H.)  Centres Hospitaliers
# 3            AIN  Centre hospitalier, ex Hôpital local       Hôpitaux Locaux
# 4            AIN  Centre hospitalier, ex Hôpital local       Hôpitaux Locaux
#
#    coordxet   coordyet
# 0  870262.2  6571540.8
# 1  908313.3  6520061.2
# 2  837272.3  6539470.4
# 3  935221.3  6584833.3
# 4  870118.2  6536469.4

# %%
df_equi = pd.read_csv( "../data/raw/finess_equipements_sociaux.csv", sep=";", encoding="utf-8")
# Out:
# /tmp/ipykernel_14009/2998991303.py:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_equi = pd.read_csv( "../data/raw/finess_equipements_sociaux.csv", sep=";", encoding="utf-8")

# %%
df_equi.head()
# Out:
#   nofinesset nofinessej   de  \
# 0  010001246  010790368  926
# 1  010001246  010790368  927
# 2  010001261  010785897  908
# 3  010001295  010784270  259
# 4  010001360  010001352  657
#
#                                                libde  ta  \
# 0  Hébergement résidence autonomie personnes âgée...  11
# 1  Hébergement résidence autonomie personnes âgée...  11
# 2        Aide par le travail pour Adultes Handicapés  13
# 3                 Activ.Club et Équipe de Prévention  16
# 4            Accueil temporaire pour Personnes Âgées  11
#
#                             libta  client  \
# 0    Hébergement Complet Internat     701
# 1    Hébergement Complet Internat     701
# 2                   Semi-Internat     110
# 3  Prestation en milieu ordinaire     805
# 4    Hébergement Complet Internat     701
#
#                                            libclient sourceinfo  capinstot  \
# 0                          Personnes Agées Autonomes          R        4.0
# 1                          Personnes Agées Autonomes          9        5.0
# 2  Déficience Intellectuelle (sans autre indication)          9       50.0
# 3  Jeunes et familles en risque d'inadaptation so...          9        NaN
# 4                          Personnes Agées Autonomes          R        1.0
#
#    ...  capautot  capautm  capautf  capauthab  ageminiaut agemaxiaut  \
# 0  ...       4.0      NaN      NaN        NaN         NaN        NaN
# 1  ...       5.0      NaN      NaN        0.0         NaN        NaN
# 2  ...      50.0      NaN      NaN        NaN         NaN        NaN
# 3  ...       NaN      NaN      NaN        NaN         NaN        NaN
# 4  ...       1.0      NaN      NaN        0.0         NaN        NaN
#
#   indsupaut   dateautor  datemajaut  datemajinst
# 0         N  2017-01-03  2017-04-21   2017-02-08
# 1         N  2017-01-03  2017-04-21   2017-02-08
# 2         N  2017-01-03  2017-04-21   2004-06-15
# 3         N  2017-01-03  2017-04-21   2004-06-15
# 4         O  2005-11-07  2017-03-03   2017-03-03
#
# [5 rows x 28 columns]

# %%
import unicodedata

def clean_text(s):
    if not isinstance(s, str):
        return ""
    s = unicodedata.normalize("NFKD", s).encode("ascii", "ignore").decode("utf-8")
    s = s.replace("’", "'")
    s = " ".join(s.split())
    return s.lower()

def regrouper_categorie(cat):
    cat = clean_text(cat)

    if any(x in cat for x in [
        "ehpad", "personnes agees", "hebergement pour personnes agees", "maison de retraite", "hbergement pour personnes agees dependantes"
    ]):
        return "Personnes âgées"

    if any(x in cat for x in [
        "ime", "itep", "sessad", "enfance", "enfant", "educatif", "pedagogique", "cmpp", "scolarisation", "educative", "c.m.p.p."
    ]):
        return "Enfance"

    if any(x in cat for x in [
        "handicap", "handicape", "handicapes", "handicapees", "adapte"
    ]):
        return "Handicap"

    if any(x in cat for x in [
        "soins a domicile", "aide a domicile", "service a domicile", "a domicile"
    ]):
        return "Aide et soins à domicile"

    if any(x in cat for x in [
        "psychologique", "psy", "psychiatrie", "cmpp"
    ]):
        return "Aide psychologique"

    if any(x in cat for x in [
        "hebergement", "maison relais", "pension de famille", "maisons relais", "accueil temporaire"
    ]):
        return "Hébergement"

    if any(x in cat for x in [
        "social", "clico", "service social", "intervention educative", "club prevention"
    ]):
        return "Social"

    if any(x in cat for x in [
        "reinsertion", "adaptation", "rehabilitation", "protection des majeurs"
    ]):
        return "Réinsertion et adaptation"
    
    if any(x in cat for x in [
        "aidant", "aidants"
    ]):
        return "Aidants"
    if any(x in cat for x in [
        "cure"
    ]):
        return "Cure"

    return "Autres"


# Application
df_equi["groupe_equipement"] = df_equi["libde"].apply(regrouper_categorie)

# %%
df_equi = df_equi.drop_duplicates()

# %%
df_equi.head()
# Out:
#   nofinesset nofinessej   de  \
# 0  010001246  010790368  926
# 1  010001246  010790368  927
# 2  010001261  010785897  908
# 3  010001295  010784270  259
# 4  010001360  010001352  657
#
#                                                libde  ta  \
# 0  Hébergement résidence autonomie personnes âgée...  11
# 1  Hébergement résidence autonomie personnes âgée...  11
# 2        Aide par le travail pour Adultes Handicapés  13
# 3                 Activ.Club et Équipe de Prévention  16
# 4            Accueil temporaire pour Personnes Âgées  11
#
#                             libta  client  \
# 0    Hébergement Complet Internat     701
# 1    Hébergement Complet Internat     701
# 2                   Semi-Internat     110
# 3  Prestation en milieu ordinaire     805
# 4    Hébergement Complet Internat     701
#
#                                            libclient sourceinfo  capinstot  \
# 0                          Personnes Agées Autonomes          R        4.0
# 1                          Personnes Agées Autonomes          9        5.0
# 2  Déficience Intellectuelle (sans autre indication)          9       50.0
# 3  Jeunes et familles en risque d'inadaptation so...          9        NaN
# 4                          Personnes Agées Autonomes          R        1.0
#
#    ...  capautm  capautf  capauthab  ageminiaut  agemaxiaut indsupaut  \
# 0  ...      NaN      NaN        NaN         NaN         NaN         N
# 1  ...      NaN      NaN        0.0         NaN         NaN         N
# 2  ...      NaN      NaN        NaN         NaN         NaN         N
# 3  ...      NaN      NaN        NaN         NaN         NaN         N
# 4  ...      NaN      NaN        0.0         NaN         NaN         O
#
#     dateautor  datemajaut  datemajinst  groupe_equipement
# 0  2017-01-03  2017-04-21   2017-02-08    Personnes âgées
# 1  2017-01-03  2017-04-21   2017-02-08    Personnes âgées
# 2  2017-01-03  2017-04-21   2004-06-15           Handicap
# 3  2017-01-03  2017-04-21   2004-06-15             Autres
# 4  2005-11-07  2017-03-03   2017-03-03    Personnes âgées
#
# [5 rows x 29 columns]

# %%
# Sélection des colonnes utiles
cols = ["nofinesset", "nofinessej","libde", "libta", "libclient", "capinstot", "groupe_equipement"]
df_equi = df_equi[[c for c in cols if c in df_equi.columns]].copy()
#nettoyage nofinesset
df_equi["nofinesset"] = clean_nofiness(df_equi["nofinesset"])

# %%
df_equi.head()
# Out:
#   nofinesset nofinessej                                              libde  \
# 0  010001246  010790368  Hébergement résidence autonomie personnes âgée...
# 1  010001246  010790368  Hébergement résidence autonomie personnes âgée...
# 2  010001261  010785897        Aide par le travail pour Adultes Handicapés
# 3  010001295  010784270                 Activ.Club et Équipe de Prévention
# 4  010001360  010001352            Accueil temporaire pour Personnes Âgées
#
#                             libta  \
# 0    Hébergement Complet Internat
# 1    Hébergement Complet Internat
# 2                   Semi-Internat
# 3  Prestation en milieu ordinaire
# 4    Hébergement Complet Internat
#
#                                            libclient  capinstot  \
# 0                          Personnes Agées Autonomes        4.0
# 1                          Personnes Agées Autonomes        5.0
# 2  Déficience Intellectuelle (sans autre indication)       50.0
# 3  Jeunes et familles en risque d'inadaptation so...        NaN
# 4                          Personnes Agées Autonomes        1.0
#
#   groupe_equipement
# 0   Personnes âgées
# 1   Personnes âgées
# 2          Handicap
# 3            Autres
# 4   Personnes âgées

# %%
#jointure equipements
# LEFT JOIN - garde tout df1, complète avec df2 si existe
df_equi_tot = df_equi.merge(df_etab, on="nofinesset", how="left")

# %%
#jointure soins 
df_soins_tot = df_soins.merge(df_etab, on="nofinesset", how="left")

# %%
df_soins_tot.head()
# Out:
#   nofinesset         rsej                                        libactivite  \
# 0  010000024  CH FLEYRIAT                                           Médecine
# 1  010000024  CH FLEYRIAT                                           Médecine
# 2  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 3  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 4  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
#
#                          libmodalite  \
# 0                    Pas de modalité
# 1                    Pas de modalité
# 2            Gynécologie obstétrique
# 3  Néonatologie sans soins intensifs
# 4  Néonatologie avec soins intensifs
#
#                                             libforme     datefin  \
# 0  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 1  Hospitalisation à temps partiel de jour ou de ...  2029-02-01
# 2  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 3  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 4  Hospitalisation complète (24 heures consécutiv...  2029-02-01
#
#   groupe_activites nofinessej              rs  \
# 0         Médecine  010780054  CH DE FLEYRIAT
# 1         Médecine  010780054  CH DE FLEYRIAT
# 2      Gynécologie  010780054  CH DE FLEYRIAT
# 3      Gynécologie  010780054  CH DE FLEYRIAT
# 4      Gynécologie  010780054  CH DE FLEYRIAT
#
#                                          rslongue  ... numvoie typvoie  \
# 0  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...   900.0     RTE
# 1  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...   900.0     RTE
# 2  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...   900.0     RTE
# 3  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...   900.0     RTE
# 4  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...   900.0     RTE
#
#        voie compvoie  lieuditbp libdepartement               libcategetab  \
# 0  DE PARIS      NaN        NaN            AIN  Centre Hospitalier (C.H.)
# 1  DE PARIS      NaN        NaN            AIN  Centre Hospitalier (C.H.)
# 2  DE PARIS      NaN        NaN            AIN  Centre Hospitalier (C.H.)
# 3  DE PARIS      NaN        NaN            AIN  Centre Hospitalier (C.H.)
# 4  DE PARIS      NaN        NaN            AIN  Centre Hospitalier (C.H.)
#
#         libcategagretab  coordxet   coordyet
# 0  Centres Hospitaliers  870262.2  6571540.8
# 1  Centres Hospitaliers  870262.2  6571540.8
# 2  Centres Hospitaliers  870262.2  6571540.8
# 3  Centres Hospitaliers  870262.2  6571540.8
# 4  Centres Hospitaliers  870262.2  6571540.8
#
# [5 rows x 24 columns]

# %%
#je crée le code insee pour pouvoir faire la jointure avec les communes 
#je crée un colonne code_insee à partir de la colonne code commune et de la colonne departement
df_soins_tot.loc[:, "code_insee"] = (
    df_soins_tot["departement"].astype(str).str.zfill(2)
    + df_soins_tot["commune"].astype(str).str.zfill(3)
)

df_soins_tot.head()
# Out:
#   nofinesset         rsej                                        libactivite  \
# 0  010000024  CH FLEYRIAT                                           Médecine
# 1  010000024  CH FLEYRIAT                                           Médecine
# 2  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 3  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 4  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
#
#                          libmodalite  \
# 0                    Pas de modalité
# 1                    Pas de modalité
# 2            Gynécologie obstétrique
# 3  Néonatologie sans soins intensifs
# 4  Néonatologie avec soins intensifs
#
#                                             libforme     datefin  \
# 0  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 1  Hospitalisation à temps partiel de jour ou de ...  2029-02-01
# 2  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 3  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 4  Hospitalisation complète (24 heures consécutiv...  2029-02-01
#
#   groupe_activites nofinessej              rs  \
# 0         Médecine  010780054  CH DE FLEYRIAT
# 1         Médecine  010780054  CH DE FLEYRIAT
# 2      Gynécologie  010780054  CH DE FLEYRIAT
# 3      Gynécologie  010780054  CH DE FLEYRIAT
# 4      Gynécologie  010780054  CH DE FLEYRIAT
#
#                                          rslongue  ... typvoie      voie  \
# 0  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...     RTE  DE PARIS
# 1  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...     RTE  DE PARIS
# 2  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...     RTE  DE PARIS
# 3  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...     RTE  DE PARIS
# 4  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...     RTE  DE PARIS
#
#   compvoie lieuditbp  libdepartement               libcategetab  \
# 0      NaN       NaN             AIN  Centre Hospitalier (C.H.)
# 1      NaN       NaN             AIN  Centre Hospitalier (C.H.)
# 2      NaN       NaN             AIN  Centre Hospitalier (C.H.)
# 3      NaN       NaN             AIN  Centre Hospitalier (C.H.)
# 4      NaN       NaN             AIN  Centre Hospitalier (C.H.)
#
#         libcategagretab  coordxet   coordyet code_insee
# 0  Centres Hospitaliers  870262.2  6571540.8      01451
# 1  Centres Hospitaliers  870262.2  6571540.8      01451
# 2  Centres Hospitaliers  870262.2  6571540.8      01451
# 3  Centres Hospitaliers  870262.2  6571540.8      01451
# 4  Centres Hospitaliers  870262.2  6571540.8      01451
#
# [5 rows x 25 columns]

# %%
#fonction pour mettre les codes communes
def create_code_insee(df, dep_col="departement", com_col="commune", new_col="code_insee"):
    """
    Crée un code INSEE à partir des colonnes département et commune.
    - dep_col : colonne du département (2 chiffres)
    - com_col : colonne de la commune (3 chiffres)
    - new_col : nom de la colonne créée
    """
    
    # Vérification des colonnes
    if dep_col not in df.columns or com_col not in df.columns:
        raise ValueError(f"Colonnes manquantes : {dep_col} ou {com_col}")
    
    df = df.copy()
    
    df[new_col] = (
        df[dep_col].astype(str).str.zfill(2)
        + df[com_col].astype(str).str.zfill(3)
    )
    
    return df

# %%
df_equi_tot = create_code_insee(df_equi_tot, "departement", "commune")
df_equi_tot.head()
# Out:
#   nofinesset nofinessej_x                                              libde  \
# 0  010001246    010790368  Hébergement résidence autonomie personnes âgée...
# 1  010001246    010790368  Hébergement résidence autonomie personnes âgée...
# 2  010001261    010785897        Aide par le travail pour Adultes Handicapés
# 3  010001295    010784270                 Activ.Club et Équipe de Prévention
# 4  010001360    010001352            Accueil temporaire pour Personnes Âgées
#
#                             libta  \
# 0    Hébergement Complet Internat
# 1    Hébergement Complet Internat
# 2                   Semi-Internat
# 3  Prestation en milieu ordinaire
# 4    Hébergement Complet Internat
#
#                                            libclient  capinstot  \
# 0                          Personnes Agées Autonomes        4.0
# 1                          Personnes Agées Autonomes        5.0
# 2  Déficience Intellectuelle (sans autre indication)       50.0
# 3  Jeunes et familles en risque d'inadaptation so...        NaN
# 4                          Personnes Agées Autonomes        1.0
#
#   groupe_equipement nofinessej_y                              rs  \
# 0   Personnes âgées    010790368          MARPA DE BAGE-LA-VILLE
# 1   Personnes âgées    010790368          MARPA DE BAGE-LA-VILLE
# 2          Handicap    010785897                ESAT LES BROSSES
# 3            Autres    010784270  PREVENTION SPECIALISEE - ADSEA
# 4   Personnes âgées    010001352                MARPA LA VALETTE
#
#                               rslongue  ... typvoie           voie compvoie  \
# 0  MARPA ANNEXE DE LA MARPA DE MANZIAT  ...       R   DE LA MAIRIE      NaN
# 1  MARPA ANNEXE DE LA MARPA DE MANZIAT  ...       R   DE LA MAIRIE      NaN
# 2                     ESAT LES BROSSES  ...     NaN            NaN      NaN
# 3    SERVICE DE PREVENTION SPECIALISEE  ...       R  PAUL VERLAINE      NaN
# 4                     MARPA LA VALETTE  ...     RTE     DE MONTCET      NaN
#
#      lieuditbp  libdepartement  \
# 0          NaN             AIN
# 1          NaN             AIN
# 2  LES BROSSES             AIN
# 3          NaN             AIN
# 4          NaN             AIN
#
#                                         libcategetab  \
# 0                               Résidences autonomie
# 1                               Résidences autonomie
# 2  Etablissement et Service d'Aide par le Travail...
# 3                          Club Equipe de Prévention
# 4                               Résidences autonomie
#
#                                      libcategagretab  coordxet   coordyet  \
# 0  Etablissements d'Hébergement pour Personnes Âgées  849751.4  6581477.7
# 1  Etablissements d'Hébergement pour Personnes Âgées  849751.4  6581477.7
# 2  Etab.et Services de Travail Protégé pour Adult...  861843.3  6600001.5
# 3   Services Concourant à la Protection de l'Enfance  871756.1  6567453.0
# 4  Etablissements d'Hébergement pour Personnes Âgées  863648.5  6568876.7
#
#   code_insee
# 0      01025
# 1      01025
# 2      01433
# 3      01289
# 4      01264
#
# [5 rows x 25 columns]

# %%
df_equi_tot = create_code_insee(df_equi_tot, "departement", "commune")
df_soins_tot = create_code_insee(df_soins_tot, "departement", "commune")
df_etab = create_code_insee(df_etab, "departement", "commune")

# %%
df_equi_tot.head()
# Out:
#   nofinesset nofinessej_x                                              libde  \
# 0  010001246    010790368  Hébergement résidence autonomie personnes âgée...
# 1  010001246    010790368  Hébergement résidence autonomie personnes âgée...
# 2  010001261    010785897        Aide par le travail pour Adultes Handicapés
# 3  010001295    010784270                 Activ.Club et Équipe de Prévention
# 4  010001360    010001352            Accueil temporaire pour Personnes Âgées
#
#                             libta  \
# 0    Hébergement Complet Internat
# 1    Hébergement Complet Internat
# 2                   Semi-Internat
# 3  Prestation en milieu ordinaire
# 4    Hébergement Complet Internat
#
#                                            libclient  capinstot  \
# 0                          Personnes Agées Autonomes        4.0
# 1                          Personnes Agées Autonomes        5.0
# 2  Déficience Intellectuelle (sans autre indication)       50.0
# 3  Jeunes et familles en risque d'inadaptation so...        NaN
# 4                          Personnes Agées Autonomes        1.0
#
#   groupe_equipement nofinessej_y                              rs  \
# 0   Personnes âgées    010790368          MARPA DE BAGE-LA-VILLE
# 1   Personnes âgées    010790368          MARPA DE BAGE-LA-VILLE
# 2          Handicap    010785897                ESAT LES BROSSES
# 3            Autres    010784270  PREVENTION SPECIALISEE - ADSEA
# 4   Personnes âgées    010001352                MARPA LA VALETTE
#
#                               rslongue  ... typvoie           voie compvoie  \
# 0  MARPA ANNEXE DE LA MARPA DE MANZIAT  ...       R   DE LA MAIRIE      NaN
# 1  MARPA ANNEXE DE LA MARPA DE MANZIAT  ...       R   DE LA MAIRIE      NaN
# 2                     ESAT LES BROSSES  ...     NaN            NaN      NaN
# 3    SERVICE DE PREVENTION SPECIALISEE  ...       R  PAUL VERLAINE      NaN
# 4                     MARPA LA VALETTE  ...     RTE     DE MONTCET      NaN
#
#      lieuditbp  libdepartement  \
# 0          NaN             AIN
# 1          NaN             AIN
# 2  LES BROSSES             AIN
# 3          NaN             AIN
# 4          NaN             AIN
#
#                                         libcategetab  \
# 0                               Résidences autonomie
# 1                               Résidences autonomie
# 2  Etablissement et Service d'Aide par le Travail...
# 3                          Club Equipe de Prévention
# 4                               Résidences autonomie
#
#                                      libcategagretab  coordxet   coordyet  \
# 0  Etablissements d'Hébergement pour Personnes Âgées  849751.4  6581477.7
# 1  Etablissements d'Hébergement pour Personnes Âgées  849751.4  6581477.7
# 2  Etab.et Services de Travail Protégé pour Adult...  861843.3  6600001.5
# 3   Services Concourant à la Protection de l'Enfance  871756.1  6567453.0
# 4  Etablissements d'Hébergement pour Personnes Âgées  863648.5  6568876.7
#
#   code_insee
# 0      01025
# 1      01025
# 2      01433
# 3      01289
# 4      01264
#
# [5 rows x 25 columns]

# %%
from pyproj import Transformer

def convert_lambert_to_wgs84(
    df,
    x_col="coordxet",
    y_col="coordyet",
    lon_col="longitude",
    lat_col="latitude"
):
    """
    Convertit des coordonnées Lambert 93 (EPSG:2154) en WGS84 (EPSG:4326).
    - x_col : colonne des X Lambert 93
    - y_col : colonne des Y Lambert 93
    - lon_col : nom de la colonne longitude créée
    - lat_col : nom de la colonne latitude créée
    """

    # Vérification des colonnes
    if x_col not in df.columns or y_col not in df.columns:
        raise ValueError(f"Colonnes manquantes : {x_col} ou {y_col}")

    df = df.copy()

    # Création du transformateur
    transformer = Transformer.from_crs("EPSG:2154", "EPSG:4326", always_xy=True)

    # Conversion
    df[lon_col], df[lat_col] = transformer.transform(
        df[x_col].astype(float).values,
        df[y_col].astype(float).values
    )

    return df

# %%
df_soins_tot = convert_lambert_to_wgs84(df_soins_tot, "coordxet", "coordyet")
df_soins_tot.head()
# Out:
#   nofinesset         rsej                                        libactivite  \
# 0  010000024  CH FLEYRIAT                                           Médecine
# 1  010000024  CH FLEYRIAT                                           Médecine
# 2  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 3  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 4  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
#
#                          libmodalite  \
# 0                    Pas de modalité
# 1                    Pas de modalité
# 2            Gynécologie obstétrique
# 3  Néonatologie sans soins intensifs
# 4  Néonatologie avec soins intensifs
#
#                                             libforme     datefin  \
# 0  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 1  Hospitalisation à temps partiel de jour ou de ...  2029-02-01
# 2  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 3  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 4  Hospitalisation complète (24 heures consécutiv...  2029-02-01
#
#   groupe_activites nofinessej              rs  \
# 0         Médecine  010780054  CH DE FLEYRIAT
# 1         Médecine  010780054  CH DE FLEYRIAT
# 2      Gynécologie  010780054  CH DE FLEYRIAT
# 3      Gynécologie  010780054  CH DE FLEYRIAT
# 4      Gynécologie  010780054  CH DE FLEYRIAT
#
#                                          rslongue  ... compvoie lieuditbp  \
# 0  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...      NaN       NaN
# 1  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...      NaN       NaN
# 2  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...      NaN       NaN
# 3  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...      NaN       NaN
# 4  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...      NaN       NaN
#
#   libdepartement               libcategetab       libcategagretab  coordxet  \
# 0            AIN  Centre Hospitalier (C.H.)  Centres Hospitaliers  870262.2
# 1            AIN  Centre Hospitalier (C.H.)  Centres Hospitaliers  870262.2
# 2            AIN  Centre Hospitalier (C.H.)  Centres Hospitaliers  870262.2
# 3            AIN  Centre Hospitalier (C.H.)  Centres Hospitaliers  870262.2
# 4            AIN  Centre Hospitalier (C.H.)  Centres Hospitaliers  870262.2
#
#     coordyet code_insee longitude   latitude
# 0  6571540.8      01451  5.209181  46.222286
# 1  6571540.8      01451  5.209181  46.222286
# 2  6571540.8      01451  5.209181  46.222286
# 3  6571540.8      01451  5.209181  46.222286
# 4  6571540.8      01451  5.209181  46.222286
#
# [5 rows x 27 columns]

# %%
df_equi_tot = convert_lambert_to_wgs84(df_equi_tot, "coordxet", "coordyet")
df_etab = convert_lambert_to_wgs84(df_etab, "coordxet", "coordyet")

# %%
df_communes.head()
# Out:
#    Unnamed: 0 code_insee             nom_standard        nom_sans_pronom  \
# 0           0      01001  L'Abergement-Clémenciat  Abergement-Clémenciat
# 1           1      01002    L'Abergement-de-Varey    Abergement-de-Varey
# 2           2      01004        Ambérieu-en-Bugey      Ambérieu-en-Bugey
# 3           3      01005      Ambérieux-en-Dombes    Ambérieux-en-Dombes
# 4           4      01006                  Ambléon                Ambléon
#
#                      nom_a                      nom_de  \
# 0  à Abergement-Clémenciat  de l'Abergement-Clémenciat
# 1    à Abergement-de-Varey    de l'Abergement-de-Varey
# 2      à Ambérieu-en-Bugey         d'Ambérieu-en-Bugey
# 3    à Ambérieux-en-Dombes       d'Ambérieux-en-Dombes
# 4                à Ambléon                   d'Ambléon
#
#            nom_sans_accent   nom_standard_majuscule typecom typecom_texte  \
# 0  l-abergement-clemenciat  L'ABERGEMENT-CLÉMENCIAT     COM       commune
# 1    l-abergement-de-varey    L'ABERGEMENT-DE-VAREY     COM       commune
# 2        amberieu-en-bugey        AMBÉRIEU-EN-BUGEY     COM       commune
# 3      amberieux-en-dombes      AMBÉRIEUX-EN-DOMBES     COM       commune
# 4                  ambleon                  AMBLÉON     COM       commune
#
#    ...  longitude_mairie latitude_centre longitude_centre grille_densite  \
# 0  ...             4.921          46.153            4.926              6
# 1  ...             5.423          46.009            5.428              6
# 2  ...             5.360          45.961            5.373              2
# 3  ...             4.903          45.996            4.912              5
# 4  ...             5.601          45.750            5.594              6
#
#              grille_densite_texte niveau_equipements_services  \
# 0        Rural à habitat dispersé                         0.0
# 1        Rural à habitat dispersé                         0.0
# 2  Centres urbains intermédiaires                         3.0
# 3                   Bourgs ruraux                         1.0
# 4        Rural à habitat dispersé                         0.0
#
#                    niveau_equipements_services_texte  \
# 0                                  communes non pôle
# 1                                  communes non pôle
# 2  centres structurants d'équipements et de services
# 3        centres locaux d'équipements et de services
# 4                                  communes non pôle
#
#                           gentile  \
# 0                             NaN
# 1  Abergementais, Abergementaises
# 2          Ambarrois, Ambarroises
# 3                       Ambarrois
# 4                      Ambléonais
#
#                                        url_wikipedia  \
# 0  https://fr.wikipedia.org/wiki/fr:L'Abergement-...
# 1  https://fr.wikipedia.org/wiki/fr:L'Abergement-...
# 2  https://fr.wikipedia.org/wiki/fr:Ambérieu-en-B...
# 3  https://fr.wikipedia.org/wiki/fr:Ambérieux-en-...
# 4           https://fr.wikipedia.org/wiki/fr:Ambléon
#
#                                      url_villedereve
# 0  https://villedereve.fr/ville/01001-l-abergemen...
# 1  https://villedereve.fr/ville/01002-l-abergemen...
# 2  https://villedereve.fr/ville/01004-amberieu-en...
# 3  https://villedereve.fr/ville/01005-amberieux-e...
# 4         https://villedereve.fr/ville/01006-ambleon
#
# [5 rows x 47 columns]

# %%
#verification des codes communes : 5 chiffres
df_communes["code_insee"] = (
    df_communes["code_insee"]
        .astype(str)
        .str.zfill(5)
)

# %%
#jointures avec communes
#jointures avec communes
df_soins_tot = df_soins_tot.merge(df_communes, on="code_insee", how="left")
df_equi_tot = df_equi_tot.merge(df_communes, on="code_insee", how="left")
df_etab = df_etab.merge(df_communes, on="code_insee", how="left")
df_soins_tot.head()
# Out:
#   nofinesset         rsej                                        libactivite  \
# 0  010000024  CH FLEYRIAT                                           Médecine
# 1  010000024  CH FLEYRIAT                                           Médecine
# 2  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 3  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 4  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
#
#                          libmodalite  \
# 0                    Pas de modalité
# 1                    Pas de modalité
# 2            Gynécologie obstétrique
# 3  Néonatologie sans soins intensifs
# 4  Néonatologie avec soins intensifs
#
#                                             libforme     datefin  \
# 0  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 1  Hospitalisation à temps partiel de jour ou de ...  2029-02-01
# 2  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 3  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 4  Hospitalisation complète (24 heures consécutiv...  2029-02-01
#
#   groupe_activites nofinessej              rs  \
# 0         Médecine  010780054  CH DE FLEYRIAT
# 1         Médecine  010780054  CH DE FLEYRIAT
# 2      Gynécologie  010780054  CH DE FLEYRIAT
# 3      Gynécologie  010780054  CH DE FLEYRIAT
# 4      Gynécologie  010780054  CH DE FLEYRIAT
#
#                                          rslongue  ... longitude_mairie  \
# 0  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
# 1  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
# 2  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
# 3  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
# 4  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
#
#   latitude_centre longitude_centre grille_densite  grille_densite_texte  \
# 0          46.251            5.223            5.0         Bourgs ruraux
# 1          46.251            5.223            5.0         Bourgs ruraux
# 2          46.251            5.223            5.0         Bourgs ruraux
# 3          46.251            5.223            5.0         Bourgs ruraux
# 4          46.251            5.223            5.0         Bourgs ruraux
#
#   niveau_equipements_services  \
# 0                         2.0
# 1                         2.0
# 2                         2.0
# 3                         2.0
# 4                         2.0
#
#                    niveau_equipements_services_texte   gentile  \
# 0  centres intermédiaires d'équipements et de ser...  Viriatis
# 1  centres intermédiaires d'équipements et de ser...  Viriatis
# 2  centres intermédiaires d'équipements et de ser...  Viriatis
# 3  centres intermédiaires d'équipements et de ser...  Viriatis
# 4  centres intermédiaires d'équipements et de ser...  Viriatis
#
#                              url_wikipedia  \
# 0  https://fr.wikipedia.org/wiki/fr:Viriat
# 1  https://fr.wikipedia.org/wiki/fr:Viriat
# 2  https://fr.wikipedia.org/wiki/fr:Viriat
# 3  https://fr.wikipedia.org/wiki/fr:Viriat
# 4  https://fr.wikipedia.org/wiki/fr:Viriat
#
#                              url_villedereve
# 0  https://villedereve.fr/ville/01451-viriat
# 1  https://villedereve.fr/ville/01451-viriat
# 2  https://villedereve.fr/ville/01451-viriat
# 3  https://villedereve.fr/ville/01451-viriat
# 4  https://villedereve.fr/ville/01451-viriat
#
# [5 rows x 73 columns]

# %%
df_communes.head()
# Out:
#    Unnamed: 0 code_insee             nom_standard        nom_sans_pronom  \
# 0           0      01001  L'Abergement-Clémenciat  Abergement-Clémenciat
# 1           1      01002    L'Abergement-de-Varey    Abergement-de-Varey
# 2           2      01004        Ambérieu-en-Bugey      Ambérieu-en-Bugey
# 3           3      01005      Ambérieux-en-Dombes    Ambérieux-en-Dombes
# 4           4      01006                  Ambléon                Ambléon
#
#                      nom_a                      nom_de  \
# 0  à Abergement-Clémenciat  de l'Abergement-Clémenciat
# 1    à Abergement-de-Varey    de l'Abergement-de-Varey
# 2      à Ambérieu-en-Bugey         d'Ambérieu-en-Bugey
# 3    à Ambérieux-en-Dombes       d'Ambérieux-en-Dombes
# 4                à Ambléon                   d'Ambléon
#
#            nom_sans_accent   nom_standard_majuscule typecom typecom_texte  \
# 0  l-abergement-clemenciat  L'ABERGEMENT-CLÉMENCIAT     COM       commune
# 1    l-abergement-de-varey    L'ABERGEMENT-DE-VAREY     COM       commune
# 2        amberieu-en-bugey        AMBÉRIEU-EN-BUGEY     COM       commune
# 3      amberieux-en-dombes      AMBÉRIEUX-EN-DOMBES     COM       commune
# 4                  ambleon                  AMBLÉON     COM       commune
#
#    ...  longitude_mairie latitude_centre longitude_centre grille_densite  \
# 0  ...             4.921          46.153            4.926              6
# 1  ...             5.423          46.009            5.428              6
# 2  ...             5.360          45.961            5.373              2
# 3  ...             4.903          45.996            4.912              5
# 4  ...             5.601          45.750            5.594              6
#
#              grille_densite_texte niveau_equipements_services  \
# 0        Rural à habitat dispersé                         0.0
# 1        Rural à habitat dispersé                         0.0
# 2  Centres urbains intermédiaires                         3.0
# 3                   Bourgs ruraux                         1.0
# 4        Rural à habitat dispersé                         0.0
#
#                    niveau_equipements_services_texte  \
# 0                                  communes non pôle
# 1                                  communes non pôle
# 2  centres structurants d'équipements et de services
# 3        centres locaux d'équipements et de services
# 4                                  communes non pôle
#
#                           gentile  \
# 0                             NaN
# 1  Abergementais, Abergementaises
# 2          Ambarrois, Ambarroises
# 3                       Ambarrois
# 4                      Ambléonais
#
#                                        url_wikipedia  \
# 0  https://fr.wikipedia.org/wiki/fr:L'Abergement-...
# 1  https://fr.wikipedia.org/wiki/fr:L'Abergement-...
# 2  https://fr.wikipedia.org/wiki/fr:Ambérieu-en-B...
# 3  https://fr.wikipedia.org/wiki/fr:Ambérieux-en-...
# 4           https://fr.wikipedia.org/wiki/fr:Ambléon
#
#                                      url_villedereve
# 0  https://villedereve.fr/ville/01001-l-abergemen...
# 1  https://villedereve.fr/ville/01002-l-abergemen...
# 2  https://villedereve.fr/ville/01004-amberieu-en...
# 3  https://villedereve.fr/ville/01005-amberieux-e...
# 4         https://villedereve.fr/ville/01006-ambleon
#
# [5 rows x 47 columns]

# %%
def filter_occitanie(df, dep_col="departement"):
    """
    Filtre un DataFrame sur les départements de la région Occitanie.
    - df : DataFrame à filtrer
    - dep_col : nom de la colonne contenant le code département
    """

    departements_occitanie = [
        "09","11","12","30","31","32","34",
        "46","48","65","66","81","82"
    ]

    if dep_col not in df.columns:
        raise ValueError(f"La colonne '{dep_col}' est absente du DataFrame.")

    df = df.copy()
    df[dep_col] = df[dep_col].astype(str).str.zfill(2)

    return df[df[dep_col].isin(departements_occitanie)]

# %%
df_etab_occitanie = filter_occitanie(df_etab)

# %%
df_soins_tot.head()
# Out:
#   nofinesset         rsej                                        libactivite  \
# 0  010000024  CH FLEYRIAT                                           Médecine
# 1  010000024  CH FLEYRIAT                                           Médecine
# 2  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 3  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
# 4  010000024  CH FLEYRIAT  Gynécologie, obstétrique, néonatologie, réanim...
#
#                          libmodalite  \
# 0                    Pas de modalité
# 1                    Pas de modalité
# 2            Gynécologie obstétrique
# 3  Néonatologie sans soins intensifs
# 4  Néonatologie avec soins intensifs
#
#                                             libforme     datefin  \
# 0  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 1  Hospitalisation à temps partiel de jour ou de ...  2029-02-01
# 2  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 3  Hospitalisation complète (24 heures consécutiv...  2029-02-01
# 4  Hospitalisation complète (24 heures consécutiv...  2029-02-01
#
#   groupe_activites nofinessej              rs  \
# 0         Médecine  010780054  CH DE FLEYRIAT
# 1         Médecine  010780054  CH DE FLEYRIAT
# 2      Gynécologie  010780054  CH DE FLEYRIAT
# 3      Gynécologie  010780054  CH DE FLEYRIAT
# 4      Gynécologie  010780054  CH DE FLEYRIAT
#
#                                          rslongue  ... longitude_mairie  \
# 0  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
# 1  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
# 2  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
# 3  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
# 4  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT  ...            5.217
#
#   latitude_centre longitude_centre grille_densite  grille_densite_texte  \
# 0          46.251            5.223            5.0         Bourgs ruraux
# 1          46.251            5.223            5.0         Bourgs ruraux
# 2          46.251            5.223            5.0         Bourgs ruraux
# 3          46.251            5.223            5.0         Bourgs ruraux
# 4          46.251            5.223            5.0         Bourgs ruraux
#
#   niveau_equipements_services  \
# 0                         2.0
# 1                         2.0
# 2                         2.0
# 3                         2.0
# 4                         2.0
#
#                    niveau_equipements_services_texte   gentile  \
# 0  centres intermédiaires d'équipements et de ser...  Viriatis
# 1  centres intermédiaires d'équipements et de ser...  Viriatis
# 2  centres intermédiaires d'équipements et de ser...  Viriatis
# 3  centres intermédiaires d'équipements et de ser...  Viriatis
# 4  centres intermédiaires d'équipements et de ser...  Viriatis
#
#                              url_wikipedia  \
# 0  https://fr.wikipedia.org/wiki/fr:Viriat
# 1  https://fr.wikipedia.org/wiki/fr:Viriat
# 2  https://fr.wikipedia.org/wiki/fr:Viriat
# 3  https://fr.wikipedia.org/wiki/fr:Viriat
# 4  https://fr.wikipedia.org/wiki/fr:Viriat
#
#                              url_villedereve
# 0  https://villedereve.fr/ville/01451-viriat
# 1  https://villedereve.fr/ville/01451-viriat
# 2  https://villedereve.fr/ville/01451-viriat
# 3  https://villedereve.fr/ville/01451-viriat
# 4  https://villedereve.fr/ville/01451-viriat
#
# [5 rows x 73 columns]

# %%
df_etab_occitanie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10007 entries, 5864 to 84437
# Data columns (total 67 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   nofinesset                         10007 non-null  object
#  1   nofinessej                         10007 non-null  string
#  2   rs                                 10007 non-null  object
#  3   rslongue                           9131 non-null   object
#  4   departement                        10007 non-null  object
#  5   commune                            10007 non-null  object
#  6   complrs                            979 non-null    object
#  7   compldistrib                       1395 non-null   object
#  8   numvoie                            7900 non-null   float64
#  9   typvoie                            9364 non-null   object
#  10  voie                               9697 non-null   object
#  11  compvoie                           336 non-null    object
#  12  lieuditbp                          957 non-null    object
#  13  libdepartement                     10007 non-null  object
#  14  libcategetab                       10007 non-null  object
#  15  libcategagretab                    10007 non-null  object
#  16  coordxet                           10004 non-null  float64
#  17  coordyet                           10004 non-null  float64
#  18  code_insee                         10007 non-null  object
#  19  longitude                          10004 non-null  float64
#  20  latitude                           10004 non-null  float64
#  21  Unnamed: 0                         10005 non-null  float64
#  22  nom_standard                       10005 non-null  object
#  23  nom_sans_pronom                    10005 non-null  object
#  24  nom_a                              10005 non-null  object
#  25  nom_de                             10005 non-null  object
#  26  nom_sans_accent                    10005 non-null  object
#  27  nom_standard_majuscule             10005 non-null  object
#  28  typecom                            10005 non-null  object
#  29  typecom_texte                      10005 non-null  string
#  30  reg_code                           10005 non-null  float64
#  31  reg_nom                            10005 non-null  string
#  32  dep_code                           10005 non-null  object
#  33  dep_nom                            10005 non-null  string
#  34  canton_code                        10005 non-null  object
#  35  canton_nom                         10005 non-null  object
#  36  epci_code                          10005 non-null  object
#  37  epci_nom                           10005 non-null  string
#  38  academie_code                      10005 non-null  float64
#  39  academie_nom                       10005 non-null  object
#  40  code_postal                        10005 non-null  float64
#  41  codes_postaux                      10005 non-null  object
#  42  zone_emploi                        10005 non-null  float64
#  43  code_insee_centre_zone_emploi      10005 non-null  object
#  44  code_unite_urbaine                 10005 non-null  object
#  45  nom_unite_urbaine                  8306 non-null   object
#  46  taille_unite_urbaine               10005 non-null  float64
#  47  type_commune_unite_urbaine         10005 non-null  object
#  48  statut_commune_unite_urbaine       10005 non-null  object
#  49  population                         10005 non-null  float64
#  50  superficie_hectare                 10005 non-null  float64
#  51  superficie_km2                     10005 non-null  float64
#  52  densite                            10005 non-null  float64
#  53  altitude_moyenne                   10005 non-null  float64
#  54  altitude_minimale                  10005 non-null  float64
#  55  altitude_maximale                  10005 non-null  float64
#  56  latitude_mairie                    10005 non-null  float64
#  57  longitude_mairie                   10005 non-null  float64
#  58  latitude_centre                    10005 non-null  float64
#  59  longitude_centre                   10005 non-null  float64
#  60  grille_densite                     10005 non-null  float64
#  61  grille_densite_texte               10005 non-null  object
#  62  niveau_equipements_services        10005 non-null  float64
#  63  niveau_equipements_services_texte  10005 non-null  object
#  64  gentile                            9420 non-null   object
#  65  url_wikipedia                      10000 non-null  object
#  66  url_villedereve                    10005 non-null  object
# dtypes: float64(24), object(38), string(5)
# memory usage: 5.2+ MB

# %%
df_etab_occ = filter_occitanie(df_etab)
df_soins_occ = filter_occitanie(df_soins_tot)
df_equi_occ = filter_occitanie(df_equi_tot)

# %%
# ---------------------------------------------------------------------------
# Rapport de qualité
# ---------------------------------------------------------------------------

def quality_report(df_etab_occ: pd.DataFrame) -> dict:
    """Génère un rapport sur la qualité du jeu de données en Occitanie."""
    report = {
        "total_etablissements": len(df_etab_occ),
        "colonnes": list(df_etab_occ.columns),
        "valeurs_nulles": df_etab_occ.isnull().sum().to_dict(),
        "departements": df_etab_occ["departement"].value_counts().to_dict(),
       
    }
    return report

# %%
    # Export

df_etab_occ.to_csv("../data/processed/etablissements_occitanie.csv", index=False, encoding="utf-8")
    
    # Export aussi des tables détail pour l'API
df_equi_occ.to_csv("../data/processed/equipements_occitanie.csv", index=False, encoding="utf-8")

    
df_soins_occ.to_csv("../data/processed/activites_occitanie.csv", index=False, encoding="utf-8")
